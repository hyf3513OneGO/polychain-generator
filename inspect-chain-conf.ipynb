# %%
import rdkit
import numpy as np
import os
from rdkit import Chem
from rdkit.Chem import AllChem

# %%
result_folder = "results/task_1_repeat-5_25000_2.0_298.0k_gaff-2.11"
sdf_file = os.path.join(result_folder,"relaxed_chain.sdf")
smiles_file = os.path.join(result_folder,"psmiles.txt")
with open(smiles_file,"r") as f:
    psmiles = f.read().strip()
mol = Chem.MolFromMolFile(sdf_file, removeHs=True)
conf = mol.GetConformer()

# %%
repeat_unit_mol = Chem.MolFromSmiles(psmiles)
print(len(repeat_unit_mol.GetAtoms()))
print(psmiles)
print(len(mol.GetAtoms()))
for atom in mol.GetAtoms():
    print(atom.GetSymbol())
# Out:
# 17
# [*]CCCC1C=CNC2=CC=C2C([*])CCC1
# 75
# C
# C
# C
# C
# C
# C
# N
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# N
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# N
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# N
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# N
# C
# C
# C
# C
# C
# C
# C
# C
